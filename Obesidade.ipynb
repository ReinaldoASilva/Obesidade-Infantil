# %% [markdown]
# ### Importando Bibliotecas

# %%
import pandas as pd
import plotly
import matplotlib.pyplot as plt

# %% [markdown]
# ##### DataSet sobre Obesidade infantil
# - Qual estado está com taxas altas e taxas baixas por faixa etária
# - falar sobre a influência da má alimentação nessa

# %% [markdown]
# #### Abrir o arquivo

# %%
data_obesidade_infantil = pd.read_excel('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/obesidade_infantil.xlsx')
data_obesidade_infantil  = pd.DataFrame(data_obesidade_infantil )
data_obesidade_infantil
# Out:
#        UF       Município  Baixo Peso_n  Baixo Peso_%  Peso adequado_n  \
# 0      AC      Acrelândia           6.0          3.57            121.0
# 1      AC    Assis Brasil          15.0          8.92            110.0
# 2      AC       Brasiléia          28.0          6.51            291.0
# 3      AC          Bujari           7.0          7.00             61.0
# 4      AC        Capixaba           1.0          0.84             78.0
# ...    ..             ...           ...           ...              ...
# 16702  TO  Tocantinópolis          74.0          5.84           1080.0
# 16703  TO        Tupirama           5.0          5.74             73.0
# 16704  TO      Tupiratins           7.0          5.69            108.0
# 16705  TO    Wanderlândia          30.0          8.84            256.0
# 16706  TO    Wanderlândia          31.0          4.71            559.0
#
#        Peso adequado_%  Sobrepeso_n  Sobrepeso_%  Obesidade_n  Obesidade_%  \
# ...

# %% [markdown]
# #### Obter informações

# %%
data_obesidade_infantil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16707 entries, 0 to 16706
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   UF                           16707 non-null  object
#  1   Município                    16707 non-null  object
#  2   Baixo Peso_n                 16698 non-null  float64
#  3   Baixo Peso_%                 16707 non-null  float64
#  4   Peso adequado_n              16698 non-null  float64
#  5   Peso adequado_%              16707 non-null  float64
#  6   Sobrepeso_n                  16698 non-null  float64
#  7   Sobrepeso_%                  16707 non-null  float64
#  8   Obesidade_n                  16698 non-null  float64
#  9   Obesidade_%                  16707 non-null  float64
#  10  Total de crianças avaliadas  16707 non-null  int64
#  11  Faixa_Etária                 16707 non-null  object
# dtypes: float64(8), int64(1), object(3)
# ...

# %% [markdown]
# #### Valores Nulo

# %%
data_obesidade_infantil.isna().sum()
# Out:
# UF                             0
# Município                      0
# Baixo Peso_n                   9
# Baixo Peso_%                   0
# Peso adequado_n                9
# Peso adequado_%                0
# Sobrepeso_n                    9
# Sobrepeso_%                    0
# Obesidade_n                    9
# Obesidade_%                    0
# Total de crianças avaliadas    0
# Faixa_Etária                   0
# dtype: int64

# %%
data_obesidade_infantil.groupby('UF')[['Sobrepeso_n']].sum().plot()
# Out:
# <AxesSubplot:xlabel='UF'>

# %%
data_obesidade_infantil.to_excel('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade_tratada/obesidade_infantil_novo.xlsx')

# %% [markdown]
# ### Dataset Fatores de Risco
# Nesse data set, tenho infor sobre escolaridade, renda, atividade fisica
# pais = Se o nivel de educacao altera esse valor
# se o nivel de renda altera esse valor

# %% [markdown]
# #### Abrir o Arquivo
# fazer uma classificacao por regios

# %%
obesidade_risco = pd.read_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
obesidade_risco.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
# ...

# %% [markdown]
# #### Obter informações

# %%
obesidade_risco.shape
# Out:
# (80929, 33)

# %%
obesidade_risco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80929 entries, 0 to 80928
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   80929 non-null  int64
#  1   YearEnd                     80929 non-null  int64
#  2   LocationAbbr                80929 non-null  object
#  3   LocationDesc                80929 non-null  object
#  4   Datasource                  80929 non-null  object
#  5   Class                       80929 non-null  object
#  6   Topic                       80929 non-null  object
#  7   Question                    80929 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             80929 non-null  object
#  10  Data_Value                  72965 non-null  float64
#  11  Data_Value_Alt              72965 non-null  float64
#  12  Data_Value_Footnote_Symbol  7964 non-null   object
# ...

# %% [markdown]
# #### Valores Nulo

# %%
obesidade_risco.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit ', 'Sample_Size',
#        'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
obesidade_risco.isna().sum()
# Excluir a coluna Data_Value_Unit porque só tem valores nulos
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               80929
# Data_Value_Type                   0
# Data_Value                     7964
# Data_Value_Alt                 7964
# Data_Value_Footnote_Symbol    72965
# Data_Value_Footnote           72965
# Low_Confidence_Limit           7964
# High_Confidence_Limit          7964
# Sample_Size                    7964
# Total                         78039
# Age(years)                    63589
# Education                     69369
# Gender                        75149
# Income                        60699
# Race/Ethnicity                57809
# GeoLocation                    1512
# ClassID                           0
# TopicID                           0
# ...

# %%
obesidade_risco.drop('Data_Value_Unit', axis = 1, inplace=True)

# %%
obesidade_risco.isna().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Type                   0
# Data_Value                     7964
# Data_Value_Alt                 7964
# Data_Value_Footnote_Symbol    72965
# Data_Value_Footnote           72965
# Low_Confidence_Limit           7964
# High_Confidence_Limit          7964
# Sample_Size                    7964
# Total                         78039
# Age(years)                    63589
# Education                     69369
# Gender                        75149
# Income                        60699
# Race/Ethnicity                57809
# GeoLocation                    1512
# ClassID                           0
# TopicID                           0
# QuestionID                        0
# ...

# %%
obesidade_risco.head(2)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
#
#                                             Question Data_Value_Type  \
# 0  Percent of adults who engage in no leisure-tim...           Value
# 1  Percent of adults aged 18 years and older who ...           Value
#
#    Data_Value  ...              GeoLocation ClassID TopicID  QuestionID  \
# 0        30.6  ...                      NaN      PA     PA1        Q047
# 1        29.3  ...  (13.444304, 144.793731)     OWS    OWS1        Q036
#
# ...

# %% [markdown]
# #### Excluir colunas

# %%
obesidade_risco.drop('Data_Value_Type', axis = 1, inplace=True)
obesidade_risco.drop('Data_Value', axis = 1, inplace=True)
obesidade_risco.drop('GeoLocation', axis = 1, inplace=True)
obesidade_risco.drop('ClassID', axis = 1, inplace=True)
obesidade_risco.drop('TopicID', axis = 1, inplace=True)
obesidade_risco.drop('QuestionID', axis = 1, inplace=True)
obesidade_risco.drop('DataValueTypeID', axis = 1, inplace=True)
obesidade_risco.drop('LocationID', axis = 1, inplace=True)
obesidade_risco.drop('StratificationCategoryId1', axis = 1, inplace=True)
obesidade_risco.drop('StratificationID1', axis = 1, inplace=True)
obesidade_risco.drop('Sample_Size', axis = 1, inplace=True)
obesidade_risco.drop('Data_Value_Alt', axis = 1, inplace=True)
obesidade_risco.drop('Data_Value_Footnote_Symbol', axis = 1, inplace=True)
obesidade_risco.drop('Data_Value_Footnote', axis = 1, inplace=True)

# %%
obesidade_risco.head(1)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
#
#                                    Datasource              Class  \
# 0  Behavioral Risk Factor Surveillance System  Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
#
#                                             Question  Low_Confidence_Limit  \
# 0  Percent of adults who engage in no leisure-tim...                  29.4
#
#    High_Confidence_Limit  Total Age(years) Education Gender Income  \
# 0                    31.8   NaN        NaN       NaN    NaN    NaN
#
#   Race/Ethnicity StratificationCategory1 Stratification1
# 0       Hispanic          Race/Ethnicity        Hispanic

# %%
obesidade_risco.to_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade_tratada/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')

# %%
obesidade_risco['Class'].unique()
# Out:
# array(['Physical Activity', 'Obesity / Weight Status',
#        'Fruits and Vegetables'], dtype=object)

# %% [markdown]
# ### Dataset média móvel infantil
#
# eliminar e editar colunas
# fazer classificação entre sexo
#
# mostrar como a obesidade infantil evoluiu no decorrer dos anos e mostrar as causas dessa evolucao

# %% [markdown]
# #### Abrir o Arquivo

# %%
obesidade_media = pd.read_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/NCD_RisC_Lancet_2020_BMI_child_adolescent_global.csv')
obesidade_media.head()
# Out:
#     Sex  Year  Age group  Mean BMI  Mean BMI lower 95% uncertainty interval  \
# 0  Boys  1975          5       NaN                                      NaN
# 1  Boys  1975          6       NaN                                      NaN
# 2  Boys  1975          7       NaN                                      NaN
# 3  Boys  1975          8       NaN                                      NaN
# 4  Boys  1975          9       NaN                                      NaN
#
#    Mean BMI upper 95% uncertainty interval  Mean BMI standard error  \
# 0                                      NaN                      NaN
# 1                                      NaN                      NaN
# 2                                      NaN                      NaN
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
#
#    Prevalence of BMI>2SD (obesity)  \
# 0                         0.017400
# ...

# %% [markdown]
# #### Obter informações

# %%
obesidade_media.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 19 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Sex                                                         1350 non-null   object
#  1   Year                                                        1350 non-null   int64
#  2   Age group                                                   1350 non-null   int64
#  3   Mean BMI                                                    1050 non-null   float64
#  4   Mean BMI lower 95% uncertainty interval                     1050 non-null   float64
#  5   Mean BMI upper 95% uncertainty interval                     1050 non-null   float64
#  6   Mean BMI standard error                                     1050 non-null   float64
# ...

# %%
obesidade_media
# Out:
#         Sex  Year  Age group  Prevalence of BMI>2SD (obesity)  \
# 0      Boys  1975          5                         0.017400
# 1      Boys  1975          6                         0.020233
# 2      Boys  1975          7                         0.022648
# 3      Boys  1975          8                         0.024147
# 4      Boys  1975          9                         0.024308
# ...     ...   ...        ...                              ...
# 1345  Girls  2019         15                              NaN
# 1346  Girls  2019         16                              NaN
# 1347  Girls  2019         17                              NaN
# 1348  Girls  2019         18                              NaN
# 1349  Girls  2019         19                              NaN
#
#       Prevalence of BMI>1SD (overweight)  \
# 0                               0.070040
# 1                               0.069203
# 2                               0.073367
# 3                               0.079734
# ...

# %%
obesidade_media.shape
# Out:
# (1350, 19)

# %% [markdown]
# #### Valores Nulo

# %%
obesidade_media.isnull().sum()
# Out:
# Sex                                                             0
# Year                                                            0
# Age group                                                       0
# Mean BMI                                                      300
# Mean BMI lower 95% uncertainty interval                       300
# Mean BMI upper 95% uncertainty interval                       300
# Mean BMI standard error                                       300
# Prevalence of BMI>2SD (obesity)                                90
# Prevalence of BMI>2SD lower 95% uncertainty interval           90
# Prevalence of BMI>2SD upper 95% uncertainty interval           90
# Prevalence of BMI>1SD (overweight)                             90
# Prevalence of BMI>1SD lower 95% uncertainty interval           90
# Prevalence of BMI>1SD upper 95% uncertainty interval           90
# Prevalence of BMI<minus1SD (underweight)                       90
# ...

# %%
obesidade_media.to_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade_tratada/NCD_RisC_Lancet_2020_BMI_child_adolescent_global.csv')

# %% [markdown]
# #### Excluir Colunas

# %%
obesidade_media.columns
# Out:
# Index(['Sex', 'Year', 'Age group', 'Mean BMI',
#        'Mean BMI lower 95% uncertainty interval',
#        'Mean BMI upper 95% uncertainty interval', 'Mean BMI standard error',
#        'Prevalence of BMI>2SD (obesity)',
#        'Prevalence of BMI>2SD lower 95% uncertainty interval',
#        'Prevalence of BMI>2SD upper 95% uncertainty interval',
#        'Prevalence of BMI>1SD (overweight)',
#        'Prevalence of BMI>1SD lower 95% uncertainty interval',
#        'Prevalence of BMI>1SD upper 95% uncertainty interval',
#        'Prevalence of BMI<minus1SD (underweight)',
#        'Prevalence of BMI<minus1SD lower 95% uncertainty interval',
#        'Prevalence of BMI<minus1SD upper 95% uncertainty interval',
#        'Prevalence of BMI<minus2SD (moderate & severe underweight)',
#        'Prevalence of BMI<minus2SD lower 95% uncertainty interval',
#        'Prevalence of BMI<minus2SD upper 95% uncertainty interval'],
#       dtype='object')

# %%
obesidade_media.drop('Mean BMI lower 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Mean BMI upper 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Mean BMI standard error', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI>2SD lower 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI>2SD upper 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI>1SD lower 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI>1SD upper 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI<minus1SD lower 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI<minus1SD upper 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI<minus2SD lower 95% uncertainty interval', axis = 1, inplace=True)
obesidade_media.drop('Prevalence of BMI<minus2SD upper 95% uncertainty interval', axis = 1, inplace=True)

# %%
obesidade_media.drop('Mean BMI', axis = 1, inplace=True)

# %%
obesidade_media
# Out:
#         Sex  Year  Age group  Prevalence of BMI>2SD (obesity)  \
# 0      Boys  1975          5                         0.017400
# 1      Boys  1975          6                         0.020233
# 2      Boys  1975          7                         0.022648
# 3      Boys  1975          8                         0.024147
# 4      Boys  1975          9                         0.024308
# ...     ...   ...        ...                              ...
# 1345  Girls  2019         15                              NaN
# 1346  Girls  2019         16                              NaN
# 1347  Girls  2019         17                              NaN
# 1348  Girls  2019         18                              NaN
# 1349  Girls  2019         19                              NaN
#
#       Prevalence of BMI>1SD (overweight)  \
# 0                               0.070040
# 1                               0.069203
# 2                               0.073367
# 3                               0.079734
# ...

# %%
obesidade_media.to_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade_tratada/NCD_RisC_Lancet_2020_BMI_child_adolescent_global.csv')

# %% [markdown]
# #### Dataset Causas de morte

# %% [markdown]
# #### Abrir o Arquivo

# %%
obesidade_causas_de_morte = pd.read_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/number-of-deaths-by-risk-factor.csv')
obesidade_causas_de_morte
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                                  3169
# 1                                                  3222
# 2                                                  3395
# 3                                                  3623
# 4                                                  3788
# ...                                                 ...
# 6835                                               2835
# 6836                                               2781
# ...

# %% [markdown]
# #### Obter informações

# %%
obesidade_causas_de_morte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 31 columns):
#  #   Column                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                            --------------  -----
#  0   Entity                                                                                                            6840 non-null   object
#  1   Code                                                                                                              6150 non-null   object
#  2   Year                                                                                                              6840 non-null   int64
#  3   Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)              6840 non-null   int64
# ...

# %%
obesidade_causas_de_morte.shape
# Out:
# (6840, 31)

# %%
obesidade_causas_de_morte
# Out:
#               Year  \
# count  6840.000000
# mean   2004.500000
# std       8.656074
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# count                                       6.840000e+03
# mean                                        8.458244e+04
# std                                         3.511973e+05
# min                                         0.000000e+00
# 25%                                         4.337500e+02
# 50%                                         2.101000e+03
# 75%                                         1.181025e+04
# max                                         4.506193e+06
#
#        Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# count                                       6.840000e+03
# ...

# %% [markdown]
# #### Valores Nulo

# %%
obesidade_causas_de_morte.isnull().sum()
# Out:
# Entity                                                                                                                0
# Code                                                                                                                690
# Year                                                                                                                  0
# Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)                  0
# Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)                  0
# Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)                           0
# Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)                      0
# Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)                                   0
# ...

# %% [markdown]
# #### Colunas a serem utilizadas

# %% [markdown]
# doencas
# 'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)',
# 'Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)',
#
# alimentacao
# 'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)',
# 'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)',
# 'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)',
# 'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)',
# 'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)',
#  'Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)'
#  Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)
#
# atividades
# 'Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)',
# 'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)',

# %% [markdown]
# #### Excluir colunas

# %%
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Iron deficiency - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Child stunting - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Vitamin A deficiency - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Low bone mineral density - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Drug use - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: No access to handwashing facility - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/Obesidade.ipynb Célula: 42 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/Obesidade.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
#       <a href='vscode-notebook-cell:/Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/Obesidade.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)
# ...

# %%
obesidade_causas_de_morte.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)',
# ...

# %%
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)

# %%
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)

# %%
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)

# %%
obesidade_causas_de_morte.drop('Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)', axis = 1, inplace=True)

# %%
obesidade_causas_de_morte.drop('Code', axis = 1, inplace=True)

# %% [markdown]
# #### Renomear as colunas

# %%
obesidade_causas_de_morte
# Out:
#            Entity  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 6835     Zimbabwe  2015
# 6836     Zimbabwe  2016
# 6837     Zimbabwe  2017
# 6838     Zimbabwe  2018
# 6839     Zimbabwe  2019
#
#       Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                                 25633
# 1                                                 25872
# 2                                                 26309
# 3                                                 26961
# 4                                                 27658
# ...                                                 ...
# 6835                                              11483
# 6836                                              11663
# 6837                                              11819
# ...

# %%
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)':'High systolic blood pressure'})
# Out:
# Index(['Entity', 'Year', 'High systolic blood pressure',
#        'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)',
# ...

# %%
obesidade_causas_de_morte = obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)':'Diet high in sodium'})
obesidade_causas_de_morte.columns
# Out:
# Index(['Entity', 'Year', 'High systolic blood pressure', 'Diet high in sodium',
#        'Diet low in whole grains', 'Diet low in fruits', 'Low birth weight',
#        'Diet low in nuts and seeds', 'Diet low in vegetables',
#        'Low physical activity', 'High fasting plasma glucose',
#        'High body-mass index', 'Discontinued breastfeeding',
#        'Non-exclusive breastfeeding'],
#       dtype='object')

# %%
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)':'Diet low in whole grains'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)':'Diet low in fruits'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)':'Low birth weight'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)':'Diet low in nuts and seeds'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)':'Diet low in vegetables'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)':'Low physical activity'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)':'High fasting plasma glucose'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)':'High body-mass index'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Discontinued breastfeeding - Sex: Both - Age: All Ages (Number)':'Discontinued breastfeeding'})
obesidade_causas_de_morte =obesidade_causas_de_morte.rename( columns= {'Deaths - Cause: All causes - Risk: Non-exclusive breastfeeding - Sex: Both - Age: All Ages (Number)':'Non-exclusive breastfeeding'})

# %%
obesidade_causas_de_morte
# Out:
#            Entity  Year  High systolic blood pressure  Diet high in sodium  \
# 0     Afghanistan  1990                         25633                 1045
# 1     Afghanistan  1991                         25872                 1055
# 2     Afghanistan  1992                         26309                 1075
# 3     Afghanistan  1993                         26961                 1103
# 4     Afghanistan  1994                         27658                 1134
# ...           ...   ...                           ...                  ...
# 6835     Zimbabwe  2015                         11483                 1063
# 6836     Zimbabwe  2016                         11663                 1082
# 6837     Zimbabwe  2017                         11819                 1098
# 6838     Zimbabwe  2018                         12002                 1117
# 6839     Zimbabwe  2019                         12241                 1140
#
# ...

# %%
obesidade_causas_de_morte.to_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade_tratada/number-of-deaths-by-risk-factor.csv')
