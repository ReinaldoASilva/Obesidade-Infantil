# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Causas de morte
data_obesidade = pd.read_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/number-of-deaths-by-risk-factor.csv')
data_obesidade.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                               3169
# 1                                               3222
# 2                                               3395
# 3                                               3623
# 4                                               3788
#
#    Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                              25633
# 1                                              25872
# 2                                              26309
# 3                                              26961
# 4                                              27658
#
# ...

# %%
### colunas a serem usadas
doencas
'Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)',
'Deaths - Cause: All causes - Risk: High fasting plasma glucose - Sex: Both - Age: All Ages (Number)',
drogas
'Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)',

alimentacao
'Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)',
'Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)',
'Deaths - Cause: All causes - Risk: Diet low in fruits - Sex: Both - Age: All Ages (Number)',
'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)',
'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)',

atividades
'Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)',
'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)',

# %%
data_obesidade.columns[10:]
# Out:
# Index(['Deaths - Cause: All causes - Risk: Secondhand smoke - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low birth weight - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Child wasting - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Unsafe sex - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in nuts and seeds - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Diet low in vegetables - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)',
#        'Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: All Ages (Number)',
# ...

# %%
frequencia = pd.crosstab(data_obesity.Stratification1,
                        data_obesity.Topic).mean() *100
frequencia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/obesidadedados.ipynb Célula: 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/obesidadedados.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> frequencia = pd.crosstab(data_obesity.Stratification1,
#       <a href='vscode-notebook-cell:/Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/obesidadedados.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>                         data_obesity.Topic).mean() *100
#       <a href='vscode-notebook-cell:/Users/reinaldoblack/Documents/documentos/github/streamlit/Projeto-Final/obesidadedados.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> frequencia
#
# NameError: name 'data_obesity' is not defined

# %%
data_obesidade['Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)']
# Out:
# 0       25633
# 1       25872
# 2       26309
# 3       26961
# 4       27658
#         ...
# 6835    11483
# 6836    11663
# 6837    11819
# 6838    12002
# 6839    12241
# Name: Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number), Length: 6840, dtype: int64

# %%
data_obesidade.shape
# Out:
# (6840, 31)

# %%
data_obesidade = pd.read_csv('/Users/reinaldoblack/Downloads/Illinois_Obesity_By_County.csv')
data_obesidade.head(5)
# Out:
#    FID          County  Percent_1   SHAPE_Length    SHAPE_Area
# 0    1  McHenry County       27.7  522324.304452  1.702763e+10
# 1    2    Boone County       33.7  375171.144202  7.862723e+09
# 2    3     Ogle County       31.2  651729.421103  2.128458e+10
# 3    4     Will County       28.0  779085.214771  2.366943e+10
# 4    5  LaSalle County       27.1  825360.163706  3.200844e+10

# %%
#mortes sobre obesidade

data_obesidade = pd.read_csv('/Users/reinaldoblack/Downloads/IDF (deaths-attributable-to-diabetes).csv')

data_obesidade.head(5)
# Out:
#    #                        Region             Country/Territory 2000  \
# 0  1                        Africa                        Africa  NaN
# 1  2                        Europe                        Europe  NaN
# 2  3  Middle East and North Africa  Middle East and North Africa  NaN
# 3  4   North America and Caribbean   North America and Caribbean  NaN
# 4  5     South and Central America     South and Central America  NaN
#
#       2011       2021 2030 2045    Type
# 0  344,500    416,163  NaN  NaN  Region
# 1  600,000  1,111,201    0  NaN  Region
# 2  276,400    796,362  NaN  NaN  Region
# 3  280,800    930,692  NaN  NaN  Region
# 4  227,200    410,206    0  NaN  Region

# %%
data_obesidade.describe()
# Out:
#                 #
# count  231.000000
# mean   116.000000
# std     66.828138
# min      1.000000
# 25%     58.500000
# 50%    116.000000
# 75%    173.500000
# max    231.000000

# %% [markdown]
# ## media movel obesidade infantil
# eliminei colunas que nao precisavam para essa analise

# %%
data_obesidade = pd.read_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/NCD_RisC_Lancet_2020_BMI_child_adolescent_global.csv')
data_obesidade.head()
# Out:
#     Sex  Year  Age group  Mean BMI  Mean BMI lower 95% uncertainty interval  \
# 0  Boys  1975          5       NaN                                      NaN
# 1  Boys  1975          6       NaN                                      NaN
# 2  Boys  1975          7       NaN                                      NaN
# 3  Boys  1975          8       NaN                                      NaN
# 4  Boys  1975          9       NaN                                      NaN
#
#    Mean BMI upper 95% uncertainty interval  Mean BMI standard error  \
# 0                                      NaN                      NaN
# 1                                      NaN                      NaN
# 2                                      NaN                      NaN
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
#
#    Prevalence of BMI>2SD (obesity)  \
# 0                         0.017400
# ...

# %%
data_obesidade.shape
# Out:
# (1350, 19)

# %%
data_obesidade.query('Sex=="Boys" and `Age group`==5')['Prevalence of BMI>1SD (overweight)'].plot()
# Out:
# <AxesSubplot:>

# %%
data_obesidade.query('Sex=="Girls" and `Age group`==5')['Prevalence of BMI>2SD (obesity)'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# exclusao de colunas que nao serao utilizadas nessa abordagem

# %%
data_obesidade.drop('Mean BMI lower 95% uncertainty interval', axis = 1, inplace=True)

# %%
data_obesidade
# Out:
#         Sex  Year  Age group   Mean BMI  Prevalence of BMI>2SD (obesity)  \
# 0      Boys  1975          5        NaN                         0.017400
# 1      Boys  1975          6        NaN                         0.020233
# 2      Boys  1975          7        NaN                         0.022648
# 3      Boys  1975          8        NaN                         0.024147
# 4      Boys  1975          9        NaN                         0.024308
# ...     ...   ...        ...        ...                              ...
# 1345  Girls  2019         15  20.589981                              NaN
# 1346  Girls  2019         16  21.057057                              NaN
# 1347  Girls  2019         17  21.395033                              NaN
# 1348  Girls  2019         18  21.648782                              NaN
# 1349  Girls  2019         19  21.863181                              NaN
#
#       Prevalence of BMI>1SD (overweight)  \
# 0                               0.070040
# ...

# %%
data_obesidade = data_obesidade.to_csv('obesidade_limpo.csv')

# %% [markdown]
# ### novo dataset

# %%
data_obesidade = pd.read_csv('/Users/reinaldoblack/Downloads/ncd.risc/NCD_RisC_Lancet_2016_DM_age_standardised_countries.csv')
data_obesidade.head(40)
# Out:
#    Country/Region/World  ISO  Sex  Year  Age-standardised diabetes prevalence  \
# 0           Afghanistan  AFG  Men  1980                              0.044712
# 1           Afghanistan  AFG  Men  1981                              0.046114
# 2           Afghanistan  AFG  Men  1982                              0.047601
# 3           Afghanistan  AFG  Men  1983                              0.049173
# 4           Afghanistan  AFG  Men  1984                              0.050834
# 5           Afghanistan  AFG  Men  1985                              0.052550
# 6           Afghanistan  AFG  Men  1986                              0.054326
# 7           Afghanistan  AFG  Men  1987                              0.056199
# 8           Afghanistan  AFG  Men  1988                              0.058111
# 9           Afghanistan  AFG  Men  1989                              0.060041
# 10          Afghanistan  AFG  Men  1990                              0.061930
# ...

# %%
data_obesidade = data_obesidade.rename( columns= {'Country/Region/World':'Country'})
data_obesidade.columns
# Out:
# Index(['Country', 'ISO', 'Sex', 'Year', 'Age-standardised diabetes prevalence',
#        'Lower 95% uncertainty interval', 'Upper 95% uncertainty interval'],
#       dtype='object')

# %% [markdown]
# #### outro data set

# %% [markdown]
# ### COM ESSE DATA SET EU CONSIGO EXTRAIR INFORMACOES SOBRE OBESIDADE, ATIVIDADE FISICA, ETINIA, ESCOLARIDADE E RENDA

# %% [markdown]
# ## base de dados
# site: https://chronicdata.cdc.gov/Nutrition-Physical-Activity-and-Obesity/Nutrition-Physical-Activity-and-Obesity-Behavioral/hn4x-zwk7
#
# Eliminar colunas
# Editar colunas
# renomear colunas
# fazer cruzamento de dados

# %%
data = pd.read_csv('/Users/reinaldoblack/Documents/documentos/projeto final/obesidade/number-of-deaths-by-risk-factor.csv')
data = pd.DataFrame(data)
data.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                               3169
# 1                                               3222
# 2                                               3395
# 3                                               3623
# 4                                               3788
#
#    Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                              25633
# 1                                              25872
# 2                                              26309
# 3                                              26961
# 4                                              27658
#
# ...

# %%
data['LocationDesc'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LocationDesc'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data['LocationDesc']
# Out:
# 0         National
# 1             Guam
# 2         National
# 3         National
# 4         National
#            ...
# 80924       Hawaii
# 80925    Tennessee
# 80926      Florida
# 80927    Louisiana
# 80928      Arizona
# Name: LocationDesc, Length: 80929, dtype: object

# %%
### https://apps.who.int/gho/data/view.main.REGION2480A?lang=en
data = pd.read_csv('/Users/reinaldoblack/Downloads/data-2.csv')
data = pd.DataFrame(data)
data
# Out:
#               Unnamed: 0                                               2016  \
# 0                    NaN  Prevalence of obesity among adults, BMI &Great...
# 1                    NaN                                         18+  years
# 2             WHO region                                         Both sexes
# 3                 Global                                   13.1 [12.4-13.9]
# 4                 Africa                                    10.6 [9.6-11.7]
# 5               Americas                                   28.6 [26.6-30.5]
# 6        South-East Asia                                      4.7 [3.9-5.6]
# 7                 Europe                                   23.3 [21.7-24.9]
# 8  Eastern Mediterranean                                   20.8 [19.1-22.6]
# 9        Western Pacific                                      6.4 [5.2-7.7]
#
#                                               2016.1  \
# 0  Prevalence of obesity among adults, BMI &Great...
# ...

# %% [markdown]
# ##

# %%
data = pd.read_csv('/Users/reinaldoblack/Downloads/NWS-10.csv')
data = pd.DataFrame(data)
data
# Out:
#                                                 Title    Code  \
# 0   Reduce consumption of added sugars by people a...  NWS-10
# 1   Reduce consumption of added sugars by people a...  NWS-10
# 2   Reduce consumption of added sugars by people a...  NWS-10
# 3   Reduce consumption of added sugars by people a...  NWS-10
# 4   Reduce consumption of added sugars by people a...  NWS-10
# 5   Reduce consumption of added sugars by people a...  NWS-10
# 6   Reduce consumption of added sugars by people a...  NWS-10
# 7   Reduce consumption of added sugars by people a...  NWS-10
# 8   Reduce consumption of added sugars by people a...  NWS-10
# 9   Reduce consumption of added sugars by people a...  NWS-10
# 10  Reduce consumption of added sugars by people a...  NWS-10
# 11  Reduce consumption of added sugars by people a...  NWS-10
# 12  Reduce consumption of added sugars by people a...  NWS-10
# 13  Reduce consumption of added sugars by people a...  NWS-10
# ...

# %%
data.shape
# Out:
# (57, 11)
